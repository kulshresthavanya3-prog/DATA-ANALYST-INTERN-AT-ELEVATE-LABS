# %% [markdown]
# <a href="https://colab.research.google.com/github/kulshresthavanya3-prog/DATA-ANALYST-INTERN-AT-ELEVATE-LABS/blob/main/TASK1_COMPLETED(By_Vanya_Kulshrestha).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

print(os.getcwd())
# Out:
# /content

# %%
print(os.listdir())
# Out:
# ['.config', 'sample_data']

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-723e2720-556f-4f4b-8dcc-d5d3a19f5d0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-723e2720-556f-4f4b-8dcc-d5d3a19f5d0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

data = pd.read_csv('sales_data.csv')

print(data.head())
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# ...

# %%
import pandas as pd

print(data.info())
print(data.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Product_ID            1000 non-null   int64
#  1   Sale_Date             1000 non-null   object
#  2   Sales_Rep             1000 non-null   object
#  3   Region                1000 non-null   object
#  4   Sales_Amount          1000 non-null   float64
#  5   Quantity_Sold         1000 non-null   int64
#  6   Product_Category      1000 non-null   object
#  7   Unit_Cost             1000 non-null   float64
#  8   Unit_Price            1000 non-null   float64
#  9   Customer_Type         1000 non-null   object
#  10  Discount              1000 non-null   float64
#  11  Payment_Method        1000 non-null   object
#  12  Sales_Channel         1000 non-null   object
#  13  Region_and_Sales_Rep  1000 non-null   object
# dtypes: float64(4), int64(2), object(8)
# ...

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
data.describe()
# Out:
#         Product_ID  Sales_Amount  Quantity_Sold    Unit_Cost   Unit_Price  \
# count   761.000000    761.000000     761.000000   761.000000   761.000000
# mean   1050.239159   4939.600591      25.545335  2496.658844  2750.348134
# std      29.412146   2866.189176      14.156767  1420.096079  1419.943363
# min    1001.000000    100.120000       1.000000    60.280000   167.120000
# 25%    1024.000000   2381.120000      14.000000  1296.440000  1528.400000
# 50%    1051.000000   4896.930000      26.000000  2495.200000  2723.130000
# 75%    1075.000000   7370.990000      38.000000  3741.300000  4004.000000
# max    1100.000000   9976.520000      49.000000  4991.680000  5309.320000
#
#          Discount       profit
# count  761.000000   761.000000
# mean     0.154573  2442.941748
# std      0.084756  3185.378223
# min      0.010000 -4793.560000
# 25%      0.080000    70.630000
# 50%      0.150000  2382.720000
# 75%      0.230000  4935.740000
# max      0.300000  9514.560000

# %%
data = data.drop('Region', axis=1)

# %%
data['profit'] = data['Sales_Amount'] - data['Unit_Cost']

# %%
data.head(5)
# Out:
#    Product_ID   Sale_Date Sales_Rep  Sales_Amount  Quantity_Sold  \
# 0        1052  2023-02-03       Bob       5053.97             18
# 1        1093  2023-04-21       Bob       4384.02             17
# 2        1015  2023-09-21     David       4631.23             30
# 3        1072  2023-08-24       Bob       2167.94             39
# 4        1061  2023-03-24   Charlie       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel   profit
# 0           Cash        Online  4901.22
# 1           Cash        Retail   567.63
# 2  Bank Transfer        Retail  4369.67
# ...

# %%
print(data.dtypes)
# Out:
# Product_ID            int64
# Sale_Date            object
# Sales_Rep            object
# Sales_Amount        float64
# Quantity_Sold         int64
# Product_Category     object
# Unit_Cost           float64
# Unit_Price          float64
# Customer_Type        object
# Discount            float64
# Payment_Method       object
# Sales_Channel        object
# profit              float64
# dtype: object

# %%
data = data[data['Product_Category'] != 'Food']

# %%
data = data[data['Discount'] !=0]

# %%
data['Payment_Method'] = data['Payment_Method'].astype('string')

# %%
data['Sales_Channel'] = data['Sales_Channel'].astype('string')

# %%
data['Sale_Date'] = pd.to_datetime(data['Sale_Date']).dt.strftime('%d-%m-%Y')

# %%
data.head(5)
# Out:
#    Product_ID   Sale_Date Sales_Rep  Sales_Amount  Quantity_Sold  \
# 0        1052  03-02-2023       Bob       5053.97             18
# 1        1093  21-04-2023       Bob       4384.02             17
# 3        1072  24-08-2023       Bob       2167.94             39
# 4        1061  24-03-2023   Charlie       3750.20             13
# 6        1083  11-04-2023       Bob        618.31             29
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
# 6        Furniture    2408.81     2624.09     Returning      0.14
#
#   Payment_Method Sales_Channel   profit
# 0           Cash        Online  4901.22
# 1           Cash        Retail   567.63
# 3    Credit Card        Retail -2162.09
# ...
